# %% [markdown]
# <a href="https://colab.research.google.com/github/Zhuym07/PanDownloadbackup/blob/master/3D_Photo_Inpainting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **[CVPR 2020] 3D Photography using Context-aware Layered Depth Inpainting**
#
# [project website](https://shihmengli.github.io/3D-Photo-Inpainting/)

# %% [markdown]
# - **Prepare environment**

# %%
# !pip3 install torch==1.4.0+cu100 torchvision==0.5.0+cu100 -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install opencv-python==4.2.0.32
# !pip3 install vispy==0.6.4
# !pip3 install moviepy==1.0.2
# !pip3 install transforms3d==0.3.1
# !pip3 install networkx==2.3
# !sudo apt install sed
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.4.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torch-1.4.0%2Bcu100-cp36-cp36m-linux_x86_64.whl (723.9MB)
#      |████████████████████████████████| 723.9MB 25kB/s
# Collecting torchvision==0.5.0+cu100
#   Downloading https://download.pytorch.org/whl/cu100/torchvision-0.5.0%2Bcu100-cp36-cp36m-linux_x86_64.whl (4.0MB)
#      |████████████████████████████████| 4.1MB 475kB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (7.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0+cu100) (1.18.2)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.4.0
#     Uninstalling torch-1.4.0:
#       Successfully uninstalled torch-1.4.0
#   Found existing installation: torchvision 0.5.0
#     Uninstalling torchvision-0.5.0:
#       Successfully uninstalled torchvision-0.5.0
# Successfully installed torch-1.4.0+cu100 torchvision-0.5.0+cu100
# Collecting opencv-python==4.2.0.32
#   Downloading https://files.pythonhosted.org/packages/68/c5/09a1b82f940805c2cee30c3c42786651edcfd0710a0283eb09c6bc959340/opencv_python-4.2.0.32-cp36-cp36m-manylinux1_x86_64.whl (28.2MB)
#      |████████████████████████████████| 28.2MB 115kB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==4.2.0.32) (1.18.2)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-4.2.0.32
# Collecting vispy==0.6.4
#   Downloading https://files.pythonhosted.org/packages/cf/29/899797a9af4446d3ddf594f49b0fbd43076eafa1552e24690cfd99b0e2ff/vispy-0.6.4-cp36-cp36m-manylinux2010_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 11.8MB/s
# Collecting freetype-py
#   Downloading https://files.pythonhosted.org/packages/f2/00/6f332e63b33d24dc3761916e6d51402a7a82dd43c6ca8a96e24dda32c6b5/freetype_py-2.1.0.post1-py2.py3-none-manylinux1_x86_64.whl (883kB)
#      |████████████████████████████████| 890kB 52.2MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from vispy==0.6.4) (1.18.2)
# Installing collected packages: freetype-py, vispy
# Successfully installed freetype-py-2.1.0.post1 vispy-0.6.4
# Collecting moviepy==1.0.2
#   Downloading https://files.pythonhosted.org/packages/71/64/e7f0876716d5c35612bf8e9e49299d0f491285f10f36cbb481556ab0062b/moviepy-1.0.2.tar.gz (7.8MB)
#      |████████████████████████████████| 7.9MB 11.3MB/s
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.6/dist-packages (from moviepy==1.0.2) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.6/dist-packages (from moviepy==1.0.2) (4.38.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.6/dist-packages (from moviepy==1.0.2) (2.21.0)
# Collecting proglog<=1.0.0
#   Downloading https://files.pythonhosted.org/packages/fe/ab/4cb19b578e1364c0b2d6efd6521a8b4b4e5c4ae6528041d31a2a951dd991/proglog-0.1.9.tar.gz
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.6/dist-packages (from moviepy==1.0.2) (1.18.2)
# Collecting imageio<3.0,>=2.5
#   Downloading https://files.pythonhosted.org/packages/4c/2b/9dd19644f871b10f7e32eb2dbd6b45149c350b4d5f2893e091b882e03ab7/imageio-2.8.0-py3-none-any.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 48.9MB/s
# Collecting imageio_ffmpeg>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/0a/45/2472071095310b3e92010c051cbd2e3c655247ad9090851a86b8bfdcfbc5/imageio_ffmpeg-0.4.1-py3-none-manylinux2010_x86_64.whl (22.2MB)
#      |████████████████████████████████| 22.2MB 1.5MB/s
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.8.1->moviepy==1.0.2) (1.24.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio<3.0,>=2.5->moviepy==1.0.2) (7.0.0)
# Building wheels for collected packages: moviepy, proglog
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.2-cp36-none-any.whl size=110730 sha256=ffe1eb001612f22c755c1f913eea7f2fefbc02be0f21bb587a9680d573521485
#   Stored in directory: /root/.cache/pip/wheels/20/49/a9/770a9a22e7a020d796ab3784d2dc4839e38450a1ac87e6106f
#   Building wheel for proglog (setup.py) ... done
#   Created wheel for proglog: filename=proglog-0.1.9-cp36-none-any.whl size=6149 sha256=1d8f7110a305a3173c912746cc6668c6a6ec15df19c15dc02295187bf7d2cd22
#   Stored in directory: /root/.cache/pip/wheels/65/56/60/1d0306a8d90b188af393c1812ddb502a8821b70917f82dcc00
# Successfully built moviepy proglog
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: proglog, imageio, imageio-ffmpeg, moviepy
#   Found existing installation: imageio 2.4.1
#     Uninstalling imageio-2.4.1:
#       Successfully uninstalled imageio-2.4.1
#   Found existing installation: moviepy 0.2.3.5
#     Uninstalling moviepy-0.2.3.5:
#       Successfully uninstalled moviepy-0.2.3.5
# Successfully installed imageio-2.8.0 imageio-ffmpeg-0.4.1 moviepy-1.0.2 proglog-0.1.9
# Collecting transforms3d==0.3.1
#   Downloading https://files.pythonhosted.org/packages/b5/f7/e85809168a548a854d7c1331560c27b4f5381698d29c12e57759192b2bc1/transforms3d-0.3.1.tar.gz (62kB)
#      |████████████████████████████████| 71kB 9.2MB/s
# Building wheels for collected packages: transforms3d
#   Building wheel for transforms3d (setup.py) ... done
#   Created wheel for transforms3d: filename=transforms3d-0.3.1-cp36-none-any.whl size=59375 sha256=09aa9bdc8a3e085a989e1603a2fda0c53a7455237afa2c2885dfe542c5cb5248
#   Stored in directory: /root/.cache/pip/wheels/3d/3c/84/28d36677f3c760c048bd02b5a547ea0c4027770cc9cdb9af1e
# Successfully built transforms3d
# Installing collected packages: transforms3d
# Successfully installed transforms3d-0.3.1
# Collecting networkx==2.3
#   Downloading https://files.pythonhosted.org/packages/85/08/f20aef11d4c343b557e5de6b9548761811eb16e438cee3d32b1c66c8566b/networkx-2.3.zip (1.7MB)
#      |████████████████████████████████| 1.8MB 12.5MB/s
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx==2.3) (4.4.2)
# Building wheels for collected packages: networkx
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.3-py2.py3-none-any.whl size=1556408 sha256=4b69734091a6387c90bdd8d92535f33afc16bbee22c311ecdf39e442873ad1bd
#   Stored in directory: /root/.cache/pip/wheels/de/63/64/3699be2a9d0ccdb37c7f16329acf3863fd76eda58c39c737af
# Successfully built networkx
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: networkx
#   Found existing installation: networkx 2.4
#     Uninstalling networkx-2.4:
#       Successfully uninstalled networkx-2.4
# Successfully installed networkx-2.3
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# sed is already the newest version (4.4-2).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %% [markdown]
# # 新段落

# %% [markdown]
# - **Download script and pretrained model**

# %%
# %cd /content/
# !git clone https://github.com/vt-vl-lab/3d-photo-inpainting.git
# %cd 3d-photo-inpainting
# !sh download.sh
# Out:
# /content
# Cloning into '3d-photo-inpainting'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 224 (delta 6), reused 10 (delta 2), pack-reused 203
# Receiving objects: 100% (224/224), 110.86 MiB | 5.72 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# /content/3d-photo-inpainting
# --2020-04-24 13:41:47--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/color-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206331633 (197M)
# Saving to: ‘color-model.pth’
#
# color-model.pth     100%[===================>] 196.77M  5.76MB/s    in 38s
#
# 2020-04-24 13:42:26 (5.19 MB/s) - ‘color-model.pth’ saved [206331633/206331633]
#
# --2020-04-24 13:42:26--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/depth-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 206272258 (197M)
# Saving to: ‘depth-model.pth’
#
# depth-model.pth     100%[===================>] 196.72M  2.03MB/s    in 61s
#
# 2020-04-24 13:43:29 (3.21 MB/s) - ‘depth-model.pth’ saved [206272258/206272258]
#
# --2020-04-24 13:43:29--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/edge-model.pth
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45974122 (44M)
# Saving to: ‘edge-model.pth’
#
# edge-model.pth      100%[===================>]  43.84M  5.69MB/s    in 11s
#
# 2020-04-24 13:43:40 (4.11 MB/s) - ‘edge-model.pth’ saved [45974122/45974122]
#
# --2020-04-24 13:43:40--  https://filebox.ece.vt.edu/~jbhuang/project/3DPhoto/model/model.pt
# Resolving filebox.ece.vt.edu (filebox.ece.vt.edu)... 128.173.88.43
# Connecting to filebox.ece.vt.edu (filebox.ece.vt.edu)|128.173.88.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149751722 (143M)
# Saving to: ‘model.pt’
#
# model.pt            100%[===================>] 142.81M  3.81MB/s    in 40s
#
# 2020-04-24 13:44:21 (3.59 MB/s) - ‘model.pt’ saved [149751722/149751722]

# %% [markdown]
# - **Switch off off-screen rendering**

# %%
# !sed -i 's/offscreen_rendering: True/offscreen_rendering: False/g' argument.yml

# %% [markdown]
# - **Please upload `.jpg` files to `/content/3d-photo-inpainting-master/image/`**
#   - You can run this step multiple times to upload multiple `.jpg` files.

# %%
# %cd image
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# %cd ..
# Out:
# /content/3d-photo-inpainting/image
#      <input type="file" id="files-19b3cc86-527b-40c5-b3bf-1c72d70e36a9" name="files[]" multiple disabled />
#      <output id="result-19b3cc86-527b-40c5-b3bf-1c72d70e36a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 32ddf0470a305376204d1312ca4720f9.jpg to 32ddf0470a305376204d1312ca4720f9.jpg
# User uploaded file "32ddf0470a305376204d1312ca4720f9.jpg" with length 983232 bytes
# /content/3d-photo-inpainting

# %% [markdown]
# - **Execute the 3D Photo Inpainting**
#   - Note: The 3D photo generation process usually takes about 2-3 minutes or more depending on the available computing resources.

# %%
# !python main.py --config argument.yml
# Out:
#   0% 0/2 [00:00<?, ?it/s]Current Source ==>  32ddf0470a305376204d1312ca4720f9
# initialize
# device: cpu
# start processing
#   processing image/32ddf0470a305376204d1312ca4720f9.jpg (1/1)
# torch.Size([1, 3, 224, 384])
# finished
# Start Running 3D_Photo ...
# Writing mesh file mesh/32ddf0470a305376204d1312ca4720f9.ply ...
# 53.13010235415598
# Moviepy - Building video video/32ddf0470a305376204d1312ca4720f9_dolly-zoom-in.mp4.
# Moviepy - Writing video video/32ddf0470a305376204d1312ca4720f9_dolly-zoom-in.mp4
#
#   0% 0/2 [02:55<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   8% 19/241 [00:00<00:01, 184.28it/s, now=None]
# t:  16% 39/241 [00:00<00:01, 186.88it/s, now=None]
# t:  20% 49/241 [00:00<00:01, 139.93it/s, now=None]
# t:  24% 59/241 [00:00<00:02, 80.54it/s, now=None]
# t:  28% 67/241 [00:00<00:02, 64.81it/s, now=None]
# t:  31% 74/241 [00:00<00:02, 60.90it/s, now=None]
# t:  34% 81/241 [00:01<00:02, 54.16it/s, now=None]
# t:  36% 87/241 [00:01<00:03, 49.06it/s, now=None]
# t:  39% 93/241 [00:01<00:02, 49.78it/s, now=None]
# t:  41% 99/241 [00:01<00:03, 47.12it/s, now=None]
# t:  43% 104/241 [00:01<00:02, 47.53it/s, now=None]
# t:  45% 109/241 [00:01<00:02, 46.79it/s, now=None]
# t:  48% 115/241 [00:01<00:02, 45.41it/s, now=None]
# t:  50% 121/241 [00:01<00:02, 47.74it/s, now=None]
# t:  53% 127/241 [00:02<00:02, 45.60it/s, now=None]
# t:  55% 133/241 [00:02<00:02, 46.88it/s, now=None]
# t:  58% 139/241 [00:02<00:02, 46.59it/s, now=None]
# t:  60% 145/241 [00:02<00:01, 48.32it/s, now=None]
# t:  63% 151/241 [00:02<00:01, 46.34it/s, now=None]
# t:  65% 156/241 [00:02<00:01, 46.03it/s, now=None]
# t:  67% 162/241 [00:02<00:01, 47.29it/s, now=None]
# t:  69% 167/241 [00:02<00:01, 44.94it/s, now=None]
# t:  71% 172/241 [00:03<00:01, 45.71it/s, now=None]
# t:  74% 178/241 [00:03<00:01, 47.24it/s, now=None]
# t:  76% 184/241 [00:03<00:01, 48.64it/s, now=None]
# t:  78% 189/241 [00:03<00:01, 46.32it/s, now=None]
# t:  81% 195/241 [00:03<00:00, 47.19it/s, now=None]
# t:  83% 201/241 [00:03<00:00, 48.22it/s, now=None]
# t:  85% 206/241 [00:03<00:00, 47.20it/s, now=None]
# t:  88% 212/241 [00:03<00:00, 50.04it/s, now=None]
# t:  90% 218/241 [00:03<00:00, 49.11it/s, now=None]
# t:  93% 224/241 [00:04<00:00, 49.18it/s, now=None]
# t:  95% 230/241 [00:04<00:00, 49.58it/s, now=None]
# t:  98% 235/241 [00:04<00:00, 49.57it/s, now=None]
# t: 100% 241/241 [00:04<00:00, 49.64it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/32ddf0470a305376204d1312ca4720f9_dolly-zoom-in.mp4
# Moviepy - Building video video/32ddf0470a305376204d1312ca4720f9_zoom-in.mp4.
# Moviepy - Writing video video/32ddf0470a305376204d1312ca4720f9_zoom-in.mp4
#
#   0% 0/2 [03:07<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   8% 19/241 [00:00<00:01, 184.55it/s, now=None]
# t:  16% 38/241 [00:00<00:01, 185.10it/s, now=None]
# t:  20% 48/241 [00:00<00:01, 134.14it/s, now=None]
# t:  24% 58/241 [00:00<00:02, 85.39it/s, now=None]
# t:  27% 66/241 [00:00<00:02, 65.72it/s, now=None]
# t:  30% 73/241 [00:00<00:02, 56.59it/s, now=None]
# t:  33% 79/241 [00:01<00:03, 49.99it/s, now=None]
# t:  35% 85/241 [00:01<00:03, 49.57it/s, now=None]
# t:  38% 91/241 [00:01<00:03, 45.89it/s, now=None]
# t:  40% 96/241 [00:01<00:03, 45.89it/s, now=None]
# t:  42% 101/241 [00:01<00:03, 45.99it/s, now=None]
# t:  44% 106/241 [00:01<00:02, 45.23it/s, now=None]
# t:  46% 111/241 [00:01<00:03, 42.33it/s, now=None]
# t:  48% 116/241 [00:01<00:02, 43.50it/s, now=None]
# t:  50% 121/241 [00:02<00:02, 45.18it/s, now=None]
# t:  52% 126/241 [00:02<00:02, 45.35it/s, now=None]
# t:  54% 131/241 [00:02<00:02, 41.68it/s, now=None]
# t:  56% 136/241 [00:02<00:02, 43.38it/s, now=None]
# t:  59% 141/241 [00:02<00:02, 42.64it/s, now=None]
# t:  61% 147/241 [00:02<00:02, 42.25it/s, now=None]
# t:  63% 152/241 [00:02<00:02, 43.40it/s, now=None]
# t:  65% 157/241 [00:02<00:01, 44.22it/s, now=None]
# t:  67% 162/241 [00:02<00:01, 44.78it/s, now=None]
# t:  69% 167/241 [00:03<00:01, 41.79it/s, now=None]
# t:  71% 172/241 [00:03<00:01, 43.04it/s, now=None]
# t:  73% 177/241 [00:03<00:01, 44.77it/s, now=None]
# t:  76% 182/241 [00:03<00:01, 45.26it/s, now=None]
# t:  78% 187/241 [00:03<00:01, 42.77it/s, now=None]
# t:  80% 192/241 [00:03<00:01, 43.84it/s, now=None]
# t:  82% 197/241 [00:03<00:00, 44.82it/s, now=None]
# t:  84% 202/241 [00:03<00:00, 45.67it/s, now=None]
# t:  86% 207/241 [00:03<00:00, 43.29it/s, now=None]
# t:  88% 212/241 [00:04<00:00, 44.75it/s, now=None]
# t:  90% 217/241 [00:04<00:00, 44.49it/s, now=None]
# t:  92% 222/241 [00:04<00:00, 43.35it/s, now=None]
# t:  94% 227/241 [00:04<00:00, 41.89it/s, now=None]
# t:  96% 232/241 [00:04<00:00, 42.65it/s, now=None]
# t:  98% 237/241 [00:04<00:00, 44.32it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/32ddf0470a305376204d1312ca4720f9_zoom-in.mp4
# Moviepy - Building video video/32ddf0470a305376204d1312ca4720f9_circle.mp4.
# Moviepy - Writing video video/32ddf0470a305376204d1312ca4720f9_circle.mp4
#
#   0% 0/2 [03:20<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   7% 18/241 [00:00<00:01, 172.32it/s, now=None]
# t:  16% 39/241 [00:00<00:01, 179.94it/s, now=None]
# t:  20% 49/241 [00:00<00:01, 112.07it/s, now=None]
# t:  24% 58/241 [00:00<00:02, 64.42it/s, now=None]
# t:  27% 65/241 [00:00<00:03, 52.62it/s, now=None]
# t:  29% 71/241 [00:01<00:03, 44.10it/s, now=None]
# t:  32% 77/241 [00:01<00:03, 42.95it/s, now=None]
# t:  34% 82/241 [00:01<00:03, 41.29it/s, now=None]
# t:  36% 87/241 [00:01<00:04, 37.95it/s, now=None]
# t:  38% 92/241 [00:01<00:03, 37.48it/s, now=None]
# t:  40% 96/241 [00:01<00:04, 36.14it/s, now=None]
# t:  41% 100/241 [00:01<00:04, 35.01it/s, now=None]
# t:  43% 104/241 [00:01<00:03, 35.27it/s, now=None]
# t:  45% 108/241 [00:02<00:03, 33.70it/s, now=None]
# t:  46% 112/241 [00:02<00:03, 34.89it/s, now=None]
# t:  48% 116/241 [00:02<00:03, 34.15it/s, now=None]
# t:  50% 120/241 [00:02<00:03, 33.99it/s, now=None]
# t:  51% 124/241 [00:02<00:03, 34.40it/s, now=None]
# t:  53% 128/241 [00:02<00:03, 34.15it/s, now=None]
# t:  55% 132/241 [00:02<00:03, 34.12it/s, now=None]
# t:  56% 136/241 [00:02<00:03, 34.76it/s, now=None]
# t:  58% 140/241 [00:03<00:02, 35.35it/s, now=None]
# t:  60% 144/241 [00:03<00:02, 34.46it/s, now=None]
# t:  61% 148/241 [00:03<00:02, 34.81it/s, now=None]
# t:  63% 152/241 [00:03<00:02, 34.11it/s, now=None]
# t:  65% 156/241 [00:03<00:02, 35.33it/s, now=None]
# t:  66% 160/241 [00:03<00:02, 35.06it/s, now=None]
# t:  68% 164/241 [00:03<00:02, 35.25it/s, now=None]
# t:  70% 168/241 [00:03<00:02, 33.75it/s, now=None]
# t:  71% 172/241 [00:03<00:01, 34.68it/s, now=None]
# t:  73% 176/241 [00:04<00:01, 34.10it/s, now=None]
# t:  75% 180/241 [00:04<00:01, 33.62it/s, now=None]
# t:  76% 184/241 [00:04<00:01, 32.52it/s, now=None]
# t:  78% 188/241 [00:04<00:01, 33.27it/s, now=None]
# t:  80% 192/241 [00:04<00:01, 33.56it/s, now=None]
# t:  81% 196/241 [00:04<00:01, 33.92it/s, now=None]
# t:  83% 200/241 [00:04<00:01, 33.44it/s, now=None]
# t:  85% 204/241 [00:04<00:01, 33.90it/s, now=None]
# t:  86% 208/241 [00:05<00:00, 34.13it/s, now=None]
# t:  88% 212/241 [00:05<00:00, 34.52it/s, now=None]
# t:  90% 216/241 [00:05<00:00, 33.97it/s, now=None]
# t:  91% 220/241 [00:05<00:00, 34.82it/s, now=None]
# t:  93% 224/241 [00:05<00:00, 34.95it/s, now=None]
# t:  95% 228/241 [00:05<00:00, 35.08it/s, now=None]
# t:  96% 232/241 [00:05<00:00, 35.03it/s, now=None]
# t:  98% 236/241 [00:05<00:00, 34.07it/s, now=None]
# t: 100% 240/241 [00:05<00:00, 34.10it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/32ddf0470a305376204d1312ca4720f9_circle.mp4
# Moviepy - Building video video/32ddf0470a305376204d1312ca4720f9_swing.mp4.
# Moviepy - Writing video video/32ddf0470a305376204d1312ca4720f9_swing.mp4
#
#   0% 0/2 [03:34<?, ?it/s]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   9% 21/241 [00:00<00:01, 200.52it/s, now=None]
# t:  17% 40/241 [00:00<00:01, 194.89it/s, now=None]
# t:  21% 50/241 [00:00<00:01, 101.87it/s, now=None]
# t:  24% 59/241 [00:00<00:02, 76.74it/s, now=None]
# t:  28% 67/241 [00:00<00:02, 60.74it/s, now=None]
# t:  31% 74/241 [00:01<00:03, 48.17it/s, now=None]
# t:  33% 80/241 [00:01<00:03, 44.85it/s, now=None]
# t:  35% 85/241 [00:01<00:03, 42.35it/s, now=None]
# t:  37% 90/241 [00:01<00:03, 40.62it/s, now=None]
# t:  40% 96/241 [00:01<00:03, 39.89it/s, now=None]
# t:  42% 101/241 [00:01<00:03, 39.55it/s, now=None]
# t:  44% 106/241 [00:01<00:03, 39.32it/s, now=None]
# t:  46% 111/241 [00:01<00:03, 39.51it/s, now=None]
# t:  48% 116/241 [00:02<00:03, 36.40it/s, now=None]
# t:  50% 120/241 [00:02<00:03, 37.00it/s, now=None]
# t:  51% 124/241 [00:02<00:03, 36.81it/s, now=None]
# t:  53% 128/241 [00:02<00:03, 36.65it/s, now=None]
# t:  55% 132/241 [00:02<00:03, 35.66it/s, now=None]
# t:  56% 136/241 [00:02<00:02, 35.94it/s, now=None]
# t:  58% 140/241 [00:02<00:02, 35.09it/s, now=None]
# t:  60% 144/241 [00:02<00:02, 35.20it/s, now=None]
# t:  61% 148/241 [00:03<00:02, 35.58it/s, now=None]
# t:  63% 152/241 [00:03<00:02, 34.98it/s, now=None]
# t:  65% 156/241 [00:03<00:02, 36.04it/s, now=None]
# t:  66% 160/241 [00:03<00:02, 36.34it/s, now=None]
# t:  68% 165/241 [00:03<00:01, 38.04it/s, now=None]
# t:  71% 171/241 [00:03<00:01, 41.49it/s, now=None]
# t:  73% 177/241 [00:03<00:01, 42.88it/s, now=None]
# t:  76% 182/241 [00:03<00:01, 43.28it/s, now=None]
# t:  78% 187/241 [00:03<00:01, 42.55it/s, now=None]
# t:  80% 192/241 [00:04<00:01, 39.24it/s, now=None]
# t:  82% 197/241 [00:04<00:01, 40.43it/s, now=None]
# t:  84% 202/241 [00:04<00:00, 39.27it/s, now=None]
# t:  85% 206/241 [00:04<00:00, 38.12it/s, now=None]
# t:  87% 210/241 [00:04<00:00, 37.38it/s, now=None]
# t:  89% 214/241 [00:04<00:00, 35.07it/s, now=None]
# t:  90% 218/241 [00:04<00:00, 35.16it/s, now=None]
# t:  93% 223/241 [00:04<00:00, 37.95it/s, now=None]
# t:  94% 227/241 [00:05<00:00, 38.42it/s, now=None]
# t:  96% 231/241 [00:05<00:00, 38.71it/s, now=None]
# t:  98% 235/241 [00:05<00:00, 37.83it/s, now=None]
# t:  99% 239/241 [00:05<00:00, 37.72it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/32ddf0470a305376204d1312ca4720f9_swing.mp4
#  50% 1/2 [03:40<03:40, 220.84s/it]Current Source ==>  moon
# initialize
# device: cpu
# start processing
#   processing image/moon.jpg (1/1)
# torch.Size([1, 3, 384, 384])
# finished
# Start Running 3D_Photo ...
# Writing mesh file mesh/moon.ply ...
# 53.13010235415598
# Moviepy - Building video video/moon_dolly-zoom-in.mp4.
# Moviepy - Writing video video/moon_dolly-zoom-in.mp4
#
#  50% 1/2 [07:20<03:40, 220.84s/it]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   4% 9/241 [00:00<00:02, 85.73it/s, now=None]
# t:   8% 20/241 [00:00<00:02, 90.17it/s, now=None]
# t:  13% 31/241 [00:00<00:02, 93.51it/s, now=None]
# t:  18% 44/241 [00:00<00:02, 97.65it/s, now=None]
# t:  22% 52/241 [00:00<00:04, 47.05it/s, now=None]
# t:  24% 59/241 [00:01<00:05, 31.85it/s, now=None]
# t:  27% 64/241 [00:01<00:05, 29.68it/s, now=None]
# t:  29% 69/241 [00:01<00:06, 28.16it/s, now=None]
# t:  30% 73/241 [00:01<00:06, 25.62it/s, now=None]
# t:  32% 77/241 [00:01<00:06, 24.22it/s, now=None]
# t:  33% 80/241 [00:02<00:07, 21.56it/s, now=None]
# t:  34% 83/241 [00:02<00:07, 20.54it/s, now=None]
# t:  36% 87/241 [00:02<00:07, 20.96it/s, now=None]
# t:  38% 91/241 [00:02<00:07, 20.22it/s, now=None]
# t:  39% 95/241 [00:02<00:07, 20.69it/s, now=None]
# t:  41% 98/241 [00:02<00:06, 22.16it/s, now=None]
# t:  42% 101/241 [00:03<00:06, 22.89it/s, now=None]
# t:  43% 104/241 [00:03<00:06, 21.77it/s, now=None]
# t:  44% 107/241 [00:03<00:06, 20.93it/s, now=None]
# t:  46% 111/241 [00:03<00:06, 21.14it/s, now=None]
# t:  47% 114/241 [00:03<00:05, 22.90it/s, now=None]
# t:  49% 117/241 [00:03<00:05, 22.89it/s, now=None]
# t:  50% 120/241 [00:04<00:05, 21.39it/s, now=None]
# t:  51% 123/241 [00:04<00:05, 19.79it/s, now=None]
# t:  53% 127/241 [00:04<00:05, 20.29it/s, now=None]
# t:  54% 131/241 [00:04<00:05, 20.81it/s, now=None]
# t:  56% 135/241 [00:04<00:05, 20.76it/s, now=None]
# t:  58% 139/241 [00:04<00:04, 21.18it/s, now=None]
# t:  59% 143/241 [00:05<00:04, 21.08it/s, now=None]
# t:  61% 147/241 [00:05<00:04, 21.27it/s, now=None]
# t:  63% 151/241 [00:05<00:04, 21.59it/s, now=None]
# t:  64% 155/241 [00:05<00:03, 21.71it/s, now=None]
# t:  66% 159/241 [00:05<00:03, 21.66it/s, now=None]
# t:  68% 163/241 [00:06<00:03, 21.08it/s, now=None]
# t:  69% 166/241 [00:06<00:03, 23.11it/s, now=None]
# t:  70% 169/241 [00:06<00:03, 22.60it/s, now=None]
# t:  71% 172/241 [00:06<00:03, 21.64it/s, now=None]
# t:  73% 175/241 [00:06<00:03, 20.92it/s, now=None]
# t:  74% 179/241 [00:06<00:02, 20.76it/s, now=None]
# t:  76% 183/241 [00:06<00:02, 20.93it/s, now=None]
# t:  78% 187/241 [00:07<00:02, 20.86it/s, now=None]
# t:  79% 191/241 [00:07<00:02, 21.18it/s, now=None]
# t:  80% 194/241 [00:07<00:02, 22.86it/s, now=None]
# t:  82% 197/241 [00:07<00:01, 22.93it/s, now=None]
# t:  83% 200/241 [00:07<00:01, 21.53it/s, now=None]
# t:  84% 203/241 [00:07<00:01, 19.80it/s, now=None]
# t:  85% 206/241 [00:08<00:01, 21.24it/s, now=None]
# t:  87% 209/241 [00:08<00:01, 22.26it/s, now=None]
# t:  88% 212/241 [00:08<00:01, 20.46it/s, now=None]
# t:  89% 215/241 [00:08<00:01, 19.38it/s, now=None]
# t:  90% 218/241 [00:08<00:01, 21.60it/s, now=None]
# t:  92% 221/241 [00:08<00:00, 22.28it/s, now=None]
# t:  93% 224/241 [00:08<00:00, 19.80it/s, now=None]
# t:  94% 227/241 [00:09<00:00, 18.86it/s, now=None]
# t:  96% 231/241 [00:09<00:00, 19.50it/s, now=None]
# t:  98% 235/241 [00:09<00:00, 20.01it/s, now=None]
# t:  99% 238/241 [00:09<00:00, 21.90it/s, now=None]
# t: 100% 241/241 [00:09<00:00, 22.91it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_dolly-zoom-in.mp4
# Moviepy - Building video video/moon_zoom-in.mp4.
# Moviepy - Writing video video/moon_zoom-in.mp4
#
#  50% 1/2 [07:43<03:40, 220.84s/it]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   1% 2/241 [00:00<00:37,  6.32it/s, now=None]
# t:   1% 3/241 [00:00<00:34,  6.81it/s, now=None]
# t:   7% 16/241 [00:00<00:23,  9.52it/s, now=None]
# t:  12% 29/241 [00:00<00:16, 13.18it/s, now=None]
# t:  17% 42/241 [00:00<00:11, 17.99it/s, now=None]
# t:  21% 51/241 [00:01<00:09, 19.02it/s, now=None]
# t:  24% 58/241 [00:01<00:09, 20.14it/s, now=None]
# t:  27% 64/241 [00:01<00:09, 18.76it/s, now=None]
# t:  29% 69/241 [00:02<00:08, 19.50it/s, now=None]
# t:  30% 73/241 [00:02<00:08, 19.30it/s, now=None]
# t:  32% 77/241 [00:02<00:08, 18.63it/s, now=None]
# t:  33% 80/241 [00:02<00:08, 18.64it/s, now=None]
# t:  34% 83/241 [00:02<00:08, 18.15it/s, now=None]
# t:  36% 86/241 [00:02<00:07, 20.21it/s, now=None]
# t:  37% 89/241 [00:03<00:07, 19.73it/s, now=None]
# t:  38% 92/241 [00:03<00:07, 18.63it/s, now=None]
# t:  39% 95/241 [00:03<00:08, 17.98it/s, now=None]
# t:  41% 99/241 [00:03<00:07, 18.22it/s, now=None]
# t:  42% 102/241 [00:03<00:07, 19.19it/s, now=None]
# t:  43% 104/241 [00:03<00:07, 18.96it/s, now=None]
# t:  44% 107/241 [00:04<00:07, 18.32it/s, now=None]
# t:  46% 110/241 [00:04<00:06, 20.08it/s, now=None]
# t:  47% 113/241 [00:04<00:06, 19.62it/s, now=None]
# t:  48% 116/241 [00:04<00:06, 18.64it/s, now=None]
# t:  49% 119/241 [00:04<00:06, 17.95it/s, now=None]
# t:  51% 123/241 [00:04<00:06, 18.11it/s, now=None]
# t:  53% 127/241 [00:05<00:06, 18.30it/s, now=None]
# t:  54% 130/241 [00:05<00:05, 19.48it/s, now=None]
# t:  55% 132/241 [00:05<00:06, 17.87it/s, now=None]
# t:  56% 135/241 [00:05<00:06, 17.56it/s, now=None]
# t:  57% 138/241 [00:05<00:05, 19.66it/s, now=None]
# t:  59% 141/241 [00:05<00:05, 18.91it/s, now=None]
# t:  59% 143/241 [00:06<00:05, 17.08it/s, now=None]
# t:  61% 147/241 [00:06<00:05, 17.14it/s, now=None]
# t:  62% 150/241 [00:06<00:04, 19.03it/s, now=None]
# t:  63% 153/241 [00:06<00:04, 18.04it/s, now=None]
# t:  64% 155/241 [00:06<00:04, 17.29it/s, now=None]
# t:  66% 159/241 [00:06<00:04, 17.68it/s, now=None]
# t:  67% 162/241 [00:07<00:03, 19.96it/s, now=None]
# t:  68% 165/241 [00:07<00:04, 18.94it/s, now=None]
# t:  69% 167/241 [00:07<00:04, 16.32it/s, now=None]
# t:  71% 171/241 [00:07<00:04, 17.41it/s, now=None]
# t:  72% 174/241 [00:07<00:03, 19.54it/s, now=None]
# t:  73% 177/241 [00:07<00:03, 19.11it/s, now=None]
# t:  75% 180/241 [00:08<00:03, 18.48it/s, now=None]
# t:  76% 183/241 [00:08<00:03, 17.73it/s, now=None]
# t:  77% 186/241 [00:08<00:02, 18.63it/s, now=None]
# t:  78% 188/241 [00:08<00:02, 17.70it/s, now=None]
# t:  79% 191/241 [00:08<00:02, 17.04it/s, now=None]
# t:  80% 194/241 [00:08<00:02, 18.45it/s, now=None]
# t:  81% 196/241 [00:08<00:02, 17.02it/s, now=None]
# t:  83% 199/241 [00:09<00:02, 16.77it/s, now=None]
# t:  84% 202/241 [00:09<00:02, 18.90it/s, now=None]
# t:  85% 205/241 [00:09<00:02, 17.96it/s, now=None]
# t:  86% 207/241 [00:09<00:02, 16.17it/s, now=None]
# t:  88% 211/241 [00:09<00:01, 16.78it/s, now=None]
# t:  89% 214/241 [00:09<00:01, 19.15it/s, now=None]
# t:  90% 217/241 [00:10<00:01, 18.41it/s, now=None]
# t:  91% 219/241 [00:10<00:01, 16.23it/s, now=None]
# t:  92% 221/241 [00:10<00:01, 17.14it/s, now=None]
# t:  93% 223/241 [00:10<00:01, 16.42it/s, now=None]
# t:  94% 227/241 [00:10<00:00, 17.04it/s, now=None]
# t:  96% 231/241 [00:10<00:00, 17.37it/s, now=None]
# t:  97% 234/241 [00:11<00:00, 19.00it/s, now=None]
# t:  98% 236/241 [00:11<00:00, 18.03it/s, now=None]
# t:  99% 239/241 [00:11<00:00, 17.46it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_zoom-in.mp4
# Moviepy - Building video video/moon_circle.mp4.
# Moviepy - Writing video video/moon_circle.mp4
#
#  50% 1/2 [08:07<03:40, 220.84s/it]
# t:   0% 0/241 [00:00<?, ?it/s, now=None]
# t:   1% 2/241 [00:00<00:37,  6.45it/s, now=None]
# t:   1% 3/241 [00:00<00:34,  6.85it/s, now=None]
# t:   5% 11/241 [00:00<00:24,  9.42it/s, now=None]
# t:   9% 22/241 [00:00<00:16, 12.96it/s, now=None]
# t:  14% 33/241 [00:00<00:11, 17.58it/s, now=None]
# t:  19% 45/241 [00:00<00:08, 23.51it/s, now=None]
# t:  22% 53/241 [00:01<00:09, 20.77it/s, now=None]
# t:  25% 60/241 [00:01<00:09, 18.47it/s, now=None]
# t:  27% 65/241 [00:02<00:09, 18.36it/s, now=None]
# t:  29% 69/241 [00:02<00:09, 17.73it/s, now=None]
# t:  30% 73/241 [00:02<00:09, 18.34it/s, now=None]
# t:  32% 76/241 [00:02<00:09, 16.71it/s, now=None]
# t:  33% 79/241 [00:02<00:10, 16.10it/s, now=None]
# t:  34% 82/241 [00:03<00:08, 18.56it/s, now=None]
# t:  35% 85/241 [00:03<00:09, 17.23it/s, now=None]
# t:  37% 88/241 [00:03<00:09, 15.99it/s, now=None]
# t:  37% 90/241 [00:03<00:09, 16.08it/s, now=None]
# t:  38% 92/241 [00:03<00:09, 15.43it/s, now=None]
# t:  39% 94/241 [00:03<00:08, 16.52it/s, now=None]
# t:  40% 96/241 [00:04<00:09, 15.10it/s, now=None]
# t:  41% 98/241 [00:04<00:08, 16.21it/s, now=None]
# t:  41% 100/241 [00:04<00:09, 14.85it/s, now=None]
# t:  43% 103/241 [00:04<00:09, 15.19it/s, now=None]
# t:  44% 106/241 [00:04<00:07, 17.68it/s, now=None]
# t:  45% 108/241 [00:04<00:09, 14.58it/s, now=None]
# t:  46% 111/241 [00:04<00:09, 14.34it/s, now=None]
# t:  47% 113/241 [00:05<00:08, 15.52it/s, now=None]
# t:  48% 115/241 [00:05<00:08, 14.59it/s, now=None]
# t:  49% 118/241 [00:05<00:07, 16.03it/s, now=None]
# t:  50% 120/241 [00:05<00:08, 14.96it/s, now=None]
# t:  51% 123/241 [00:05<00:07, 15.04it/s, now=None]
# t:  52% 126/241 [00:05<00:06, 16.66it/s, now=None]
# t:  53% 128/241 [00:06<00:07, 14.93it/s, now=None]
# t:  54% 131/241 [00:06<00:07, 15.02it/s, now=None]
# t:  56% 134/241 [00:06<00:06, 16.84it/s, now=None]
# t:  56% 136/241 [00:06<00:06, 16.26it/s, now=None]
# t:  58% 139/241 [00:06<00:06, 15.73it/s, now=None]
# t:  59% 142/241 [00:06<00:05, 17.64it/s, now=None]
# t:  60% 144/241 [00:06<00:05, 16.35it/s, now=None]
# t:  61% 146/241 [00:07<00:05, 16.82it/s, now=None]
# t:  61% 148/241 [00:07<00:05, 16.32it/s, now=None]
# t:  63% 151/241 [00:07<00:05, 16.07it/s, now=None]
# t:  64% 154/241 [00:07<00:04, 18.43it/s, now=None]
# t:  65% 156/241 [00:07<00:05, 16.79it/s, now=None]
# t:  66% 159/241 [00:07<00:05, 16.15it/s, now=None]
# t:  67% 162/241 [00:07<00:04, 17.44it/s, now=None]
# t:  68% 164/241 [00:08<00:04, 17.01it/s, now=None]
# t:  69% 167/241 [00:08<00:04, 16.31it/s, now=None]
# t:  71% 171/241 [00:08<00:04, 16.74it/s, now=None]
# t:  72% 174/241 [00:08<00:03, 19.15it/s, now=None]
# t:  73% 177/241 [00:08<00:03, 17.46it/s, now=None]
# t:  74% 179/241 [00:09<00:03, 15.66it/s, now=None]
# t:  76% 182/241 [00:09<00:03, 16.46it/s, now=None]
# t:  76% 184/241 [00:09<00:03, 16.43it/s, now=None]
# t:  78% 187/241 [00:09<00:03, 16.09it/s, now=None]
# t:  79% 190/241 [00:09<00:03, 16.48it/s, now=None]
# t:  80% 193/241 [00:09<00:02, 18.61it/s, now=None]
# t:  81% 195/241 [00:09<00:03, 15.03it/s, now=None]
# t:  82% 198/241 [00:10<00:02, 16.56it/s, now=None]
# t:  83% 200/241 [00:10<00:02, 15.26it/s, now=None]
# t:  84% 203/241 [00:10<00:02, 15.05it/s, now=None]
# t:  85% 206/241 [00:10<00:02, 15.94it/s, now=None]
# t:  86% 208/241 [00:10<00:02, 16.35it/s, now=None]
# t:  88% 211/241 [00:10<00:01, 15.69it/s, now=None]
# t:  89% 214/241 [00:11<00:01, 17.06it/s, now=None]
# t:  90% 216/241 [00:11<00:01, 15.78it/s, now=None]
# t:  91% 219/241 [00:11<00:01, 15.74it/s, now=None]
# t:  92% 222/241 [00:11<00:01, 17.48it/s, now=None]
# t:  93% 224/241 [00:11<00:01, 16.15it/s, now=None]
# t:  94% 227/241 [00:11<00:00, 15.60it/s, now=None]
# t:  95% 230/241 [00:12<00:00, 17.45it/s, now=None]
# t:  96% 232/241 [00:12<00:00, 15.90it/s, now=None]
# t:  98% 235/241 [00:12<00:00, 15.50it/s, now=None]
# t:  99% 238/241 [00:12<00:00, 16.07it/s, now=None]
# t: 100% 240/241 [00:12<00:00, 16.72it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready video/moon_circle.mp4
#  50% 1/2 [08:22<03:40, 220.84s/it]^C

# %% [markdown]
# - **The results are stored in the following directories**
#   - Corresponding depth map estimated by [MiDaS](https://github.com/intel-isl/MiDaS.git)
#       - E.g. ```/content/3d-photo-inpainting/depth/moon.npy```
#   - Inpainted 3D mesh
#       - E.g. ```/content/3d-photo-inpainting/mesh/moon.ply```
#   - Rendered videos with zoom-in motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_zoom-in.mp4```
#   - Rendered videos with swing motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_swing.mp4```
#   - Rendered videos with circle motion
#       - E.g. ```/content/3d-photo-inpainting/video/moon_circle.mp4```
#
#     ![](https://drive.google.com/uc?id=1xBiZAeGfhsoAsG08N5UM8-f993p0G5HF)
